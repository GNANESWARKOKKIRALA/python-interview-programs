# %%
#password generator
import random
import string
length=int(input("enter the length:"))
characters=string.ascii_letters+string.digits+string.punctuation
password=""
for i in range(length):
    password+=random.choice(characters)
print("generated password:",password)
# Out:
# generated password: J_"f$=EHoQ

# %%
#OTP GENERATOR
import random

# Generate a 6 digit OTP
otp = ""
for i in range(6):
    otp += str(random.randint(0, 9))

print("Your OTP is:", otp)  # In real life this will be sent via SMS or email

# Ask user to enter OTP
user_otp = input("Enter the OTP: ")

# Verify
if user_otp == otp:
    print("OTP verified successfully!")
else:
    print("Wrong OTP. Try again.")
# Out:
# Your OTP is: 764952
# OTP verified successfully!

# %%
import random
otp=""
for i in range(9):
    otp+=str(random.randint(0,10))
print("Your OTP is:",otp)
user_otp=input("enter a the OTP:")
if user_otp==otp:
    print("The OTP is verificaed successfully")
else:
    print("Wrong OTP.Try Again")
# Out:
# Your OTP is: 5312714010
# The OTP is verificaed successfully

# %%
import random
otp=""
for i in range(8):
    otp+=str(random.randint(0,9))
print("your otp is:",otp)
user_otp=input("enter the otp ")
if user_otp==otp:
    print("OTP is verified successfully you are now logged in to the website.")
    print("https://www.flipkart.com/as-it-is-nutrition-pure-creatine-monohydrate-muscle-building-150-gm/p/itm1c9aa7edd22d9?pid=PSLGV3TCUQU4XZZJ&lid=LSTPSLGV3TCUQU4XZZJHHQOBC&marketplace=FLIPKART&q=atom%20creatine%20250g&sattr[]=quantity&sattr[]=flavor&st=flavor&otracker=AS_Query_HistoryAutoSuggest_1_4_na_na_na")
    print("")
else:
    print("wrong OTP.try again.")
# Out:
# your otp is: 43332003
# OTP is verified successfully you are now logged in to the website.
# https://www.flipkart.com/as-it-is-nutrition-pure-creatine-monohydrate-muscle-building-150-gm/p/itm1c9aa7edd22d9?pid=PSLGV3TCUQU4XZZJ&lid=LSTPSLGV3TCUQU4XZZJHHQOBC&marketplace=FLIPKART&q=atom%20creatine%20250g&sattr[]=quantity&sattr[]=flavor&st=flavor&otracker=AS_Query_HistoryAutoSuggest_1_4_na_na_na

# %%
import requests

API_KEY = "cf0ff82ba9103681ca9275e5a229870f"  # Sign up on OpenWeatherMap for free API key
BASE_URL = "http://api.openweathermap.org/data/2.5/weather?"

city = input("Enter city name: ")

# Build URL
url = BASE_URL + "q=" + city + "&appid=" + API_KEY + "&units=metric"

response = requests.get(url)
data = response.json()

if data["cod"] != "404":
    main = data["main"]
    temperature = main["temp"]
    humidity = main["humidity"]
    weather = data["weather"][0]["description"]

    print(f"\nWeather in {city}:")
    print(f"Temperature: {temperature}°C")
    print(f"Humidity: {humidity}%")
    print(f"Condition: {weather}")
else:
    print("City not found!")
# Out:
# Weather in guntur:
# Temperature: 27.14°C
# Humidity: 82%
# Condition: overcast clouds
